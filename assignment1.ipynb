# %% [markdown]
# <a href="https://colab.research.google.com/github/vanshwadhwa24/UCS420/blob/main/assignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
3# Assignment 1.1
name = input("Enter your name: ")
for i in range(3):
    print(name)
# Out:
# Enter your name: vansh
# vansh
# vansh
# vansh

# %%
# Assignment 2.1
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
c = int(input("Enter third number: "))
print(a + b + c)
# Out:
# Enter first number: 3
# Enter second number: 3
# Enter third number: 3
# 9

# %%
# Assignment 2.2
a = input("Enter first string: ")
b = input("Enter second string: ")
c = input("Enter third string: ")
print(a + b + c)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_5565/2425899363.py in <cell line: 0>()
#       1 # Assignment 2.2
# ----> 2 a = input("Enter first string: ")
#       3 b = input("Enter second string: ")
#       4 c = input("Enter third string: ")
#       5 print(a + b + c)
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
# ...

# %%
# Assignment 4.1
for i in range(1, 11):
    print(7, "*", i, "=", 7 * i)

for i in range(1, 11):
    print(9, "*", i, "=", 9 * i)

# %%
# Assignment 4.2
n = int(input("Enter a number: "))
for i in range(1, 11):
    print(n, "*", i, "=", n * i)

# %%
# Assignment 4.3
n = int(input("Enter a number: "))
s = 0
for i in range(1, n + 1):
    s = s + i
print(s)

# %%
# Assignment 5.1
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
c = int(input("Enter third number: "))
print(max(a, b, c))

# %%
# Assignment 5.2
n = int(input("Enter a number: "))
s = 0
for i in range(1, n + 1):
    if i % 7 == 0 and i % 9 == 0:
        s = s + i
print(s)

# %%
# Assignment 5.3
n = int(input("Enter a number: "))
s = 0

for x in range(2, n + 1):
    f = 0
    for i in range(2, x // 2 + 1):
        if x % i == 0:
            f = 1
            break
    if f == 0:
        s = s + x

print(s)

# %%
# Assignment 6.1
def Add_two_nums(a,b):
          c=a+b
          return c

print(Add_two_nums(4,9))

# %%
#Assignment 6.2
def IsPrime(n):
	for i in range(2, n//2 + 1):
		if n%i==0:
			return False
	return True
print(IsPrime(4))
print(IsPrime(37))

# %%
#Assignment 6.3
def AddN(n):
  sum=0
  for i in range(1,n+1):
    sum+=i
  return sum
print(AddN(10))

# %%
#Assignment 7
import math as m
print("Exponential:", m.exp(-50))
print("Log base 2:", m.log(64, 2))
print("Log base 10:", m.log(1000, 10))
print("Log10:", m.log10(1000))
print("Cosine:", m.cos(45))
print("Sine:", m.sin(45))
print("Tangent:", m.tan(45))
print("Square root:", m.sqrt(256))
print("Ceiling:", m.ceil(72.3))
print("Floor:", m.floor(72.3))

# %%
#Assignment 8.1
s= 'Vansh Wadhwa'
print(s)
print(s[0])
print(s[2:6])
print(s[:-3])

# %%
#Assignment 8.2
s= 'Vansh Wadhwa'
print(s.upper())
print(s.lower())
print(len(s))

# %%
name= input("Enter your name: ")
age= int(input("Enter your age: "))
s = "Your name is %s and your age is %d" % (name, age)
print(s)

# %%
#Assignment 8.5
var = "  Vansh Wadhwa     "
print(len(var))
print(var.strip())
print(len(var.strip()))

# %%
#Assignment 8.6
s = " VAnsh, wadhwa  "
len(s)
print(s.split())
print(s.split(' '))
print(s.split(','))
print(s.strip().split(','))

# %%
#Assignment 8.7
s = 'Vansh wadhwa'
print(s.count('wa'))

# %%
#Assignemnt 8.8
s = "Vansh"
s=s[::-1]
print(s)

# %%
#Assignemnt 8.9
s = "Vansh"
print(s==s[::-1])

# %%
#Assignment 9.1
import random as r
print(r.random())

# %%
#Assignment 9.2
import random as r
print(r.randint(1,100))

# %%
#Assignment 9.3
import random as r
print(r.uniform(1,100))

# %%
import random as r
a=[1,2,3,4,5,6,7,8,9]
print(r.sample(a,3))
print(r.sample(range(0,100),2))

# %%
#Assignment 9.5
import string as s
import random as r
print(s.ascii_letters)
pass1= r.sample(s.ascii_letters,6)
print(pass1)
pass2 = "".join(pass1)
pass3 ="+".join(pass1)
pass4="%".join(pass1)
print(pass1)
print(pass2)
print(pass3)
print(pass4)

# %%
#Assignment 9.6
import string as s
import random as r
print(s.digits)
otp = r.sample(s.digits,5)
print(otp)
print("".join(otp))
print("a".join(otp))
print("#".join(otp))

# %%
#Assignment 9.7
import string as s
import random as r
print(s.ascii_letters+s.digits)
mixpass= r.sample(s.ascii_letters +s.digits, 6)
print("".join(mixpass))
print("$".join(mixpass))
print("!".join(mixpass))

# %%
#Assignment 11.1
l = ["Vansh",'Wadhwa',24,9.992]
print(l)
print(len(l))

# %%
#Assignment 11.2
l=["vansh", 2.222,1212]
print(l)
i=0
while(i<len(l)):
  print(l[i])
  i+=1

# %%
# Assignemnt 11.3
l =["vansh","wadhwa", 211]
for i in range(0,len(l)):
  print(l[i])

# %%
#Assignment 11.4
l =["vansh", "wadhwa","is"]
for s in l:
  print(s)

# %%
l = ["vansh","wadhwa","is"]
l.append("good boy")
print(l)
del l[1]
print(l)

# %%
l =[3,4,5,6,7,8,8,1,1,2,]
print(sum(l))
print(sum(l)/len(l))
print(sum(l)//len(l))
print(L*2)
print(L+4)

# %%
#Assignment 11.7
l = [11,2,3,5,,34,5,3,677,4,3,3]
print(max(l))
print(min(l))
print(l.sort())
print(l.sort(reverse=True))

# %%
#Assignment 11.8
a=[4,5]
b=[4]
l=a+b
print(l)
print(l[1:])
print(l[:-1])

# %%
#Assignment 11.9
l=[1,4,6,9]
l = [ i*4 for i in l]
print(l)

# %%
#Assignment 11.10
l = [4,5,2,1]
print(2 in l)
print(9 in l)

# %%
#Assignment 12.1
cg = {1:3,2:5,6:4,8:4.5}
print(cg)
print(len(cg))
print(cg[1])
print(cg[6])

# %%
#Assignment 12.2
cg = {1:3,2:5,6:4,8:4.5}
for i in cg:
  print(c," : ",cg[i])

# %%
#Assignment 12.3
cg = {1:3,2:5,6:4,8:4.5}
print(cg)
print(list(cg.keys()))
print(list(cg.values()))

# %%
#Assignment 12
cg = {1:3,2:5,6:4,8:4.5}
